# %%
from scipy.stats import t, norm
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <h2 style="color:blue">Q1</h2>

# %%
df = 15
xvalue = -1.753
xticks = [xvalue, -1, 0, 1, 2]
x_fill = np.linspace(t.ppf(0.01, df), xvalue, 100)
y_fill = t.pdf(x_fill, df)

# %%
fig, ax = plt.subplots(1, 1)
area = t.cdf(xvalue, df)
x = np.linspace(t.ppf(0.01, df), t.ppf(0.99, df), 100)
ax.plot(x, t.pdf(x, df), 'b-', lw=2, alpha=0.6, label=f't(df={df})')
ax.axvline(xvalue, color='r', lw=2, alpha=0.5)
ax.axhline(0, color='black')
title = f'P(X<{xvalue})={area:.2f}'
ax.set_title(title)
ax.set_xticks(xticks)

ax.fill_between(x_fill, y_fill, 0, alpha=0.3, color='b')

ax.set_ylim(0, 0.42)
plt.tight_layout()
#plt.savefig('HW8_Q1.png', dpi=150)
plt.show()

# %% [markdown]
# <h2 style="color:blue">Q2</h2>

# %%
df = 8
xvalue = 2.306
xticks = [-xvalue, -1, 0, 1, xvalue]
x_fill_1 = np.linspace(t.ppf(0.01, df), -xvalue, 100)
y_fill_1 = t.pdf(x_fill_1, df)
x_fill_2 = np.linspace(xvalue, t.ppf(0.99, df), 100)
y_fill_2 = t.pdf(x_fill_2, df)

# %%
fig, ax = plt.subplots(1, 1)
area = 1 - (t.cdf(xvalue, df) - t.cdf(-xvalue, df))
x = np.linspace(t.ppf(0.01, df), t.ppf(0.99, df), 100)
ax.plot(x, t.pdf(x, df), 'b-', lw=2, alpha=0.6, label=f't(df={df})')
ax.axvline(-xvalue, color='r', lw=2, alpha=0.5)
ax.axvline(xvalue, color='r', lw=2, alpha=0.5)
ax.axhline(0, color='black')
title = f'P(X<{-xvalue})+P(X>{xvalue})={area:.2f}'
ax.set_title(title)
ax.set_xticks(xticks)

ax.fill_between(x_fill_1, y_fill_1, 0, alpha=0.3, color='b')
ax.fill_between(x_fill_2, y_fill_2, 0, alpha=0.3, color='b')

ax.set_ylim(0, 0.42)
plt.tight_layout()
#plt.savefig('HW8_Q2.png', dpi=150)
plt.show()

# %% [markdown]
# <h2 style="color:blue">Q3</h2>

# %%
data = [0.95, 1.02, 1.01, 0.98]
n = len(data)
mean = np.mean(data)
std = np.std(data, ddof=1)
print(f'Sample mean is {mean:.4f}')
print(f'STD is {std:.4f}')
# Out:
# Sample mean is 0.9900
# STD is 0.0316

# %%
t_critical = 3.182
left = mean - t_critical * std/np.sqrt(n)
right = mean + t_critical * std/np.sqrt(n)
print(f'The interval is from {left:.4f} to {right:.4f}')
# Out:
# The interval is from 0.9397 to 1.0403

# %%
t_sample = (mean-1)/(std/np.sqrt(n))
print(f't-sample is {t_sample:.4f}')
# Out:
# t-sample is -0.6325

# %%
df = 3
xvalue = 3.182
xticks = [-xvalue, -2, -1, 0, 1, 2, xvalue]
x_fill_1 = np.linspace(t.ppf(0.01, df), -xvalue, 100)
y_fill_1 = t.pdf(x_fill_1, df)
x_fill_2 = np.linspace(xvalue, t.ppf(0.99, df), 100)
y_fill_2 = t.pdf(x_fill_2, df)

# %%
fig, ax = plt.subplots(1, 1)
area = 1 - (t.cdf(xvalue, df) - t.cdf(-xvalue, df))
x = np.linspace(t.ppf(0.01, df), t.ppf(0.99, df), 100)
ax.plot(x, t.pdf(x, df), 'b-', lw=2, alpha=0.6, label=f't(df={df})')
ax.axvline(-xvalue, color='r', lw=2, alpha=0.5)
ax.axvline(xvalue, color='r', lw=2, alpha=0.5)
ax.axvline(t_sample, color='green', alpha=0.7, label=r'$t_{obs}=$'+f'{t_sample:.3f}')
ax.axhline(0, color='black')
title = f'P(X<{-xvalue})+P(X>{xvalue})={area:.2f}'
ax.set_title(title)
ax.set_xticks(xticks)

ax.fill_between(x_fill_1, y_fill_1, 0, alpha=0.3, color='b')
ax.fill_between(x_fill_2, y_fill_2, 0, alpha=0.3, color='b')
ax.legend()
ax.set_ylim(0, 0.42)
plt.tight_layout()
#plt.savefig('HW8_Q3.png', dpi=150)
plt.show()

# %% [markdown]
# <h2 style="color:blue">Q4</h2>

# %%
data = [2.8, 3.2, 3.75, 3.1, 2.95, 3.4]
n = len(data)
mean = np.mean(data)
std = np.std(data, ddof=1)
print(f'Sample mean is {mean:.4f}')
print(f'STD is {std:.4f}')
# Out:
# Sample mean is 3.2000
# STD is 0.3391

# %%
t_critical = 2.571
left = mean - t_critical * std/np.sqrt(n)
right = mean + t_critical * std/np.sqrt(n)
print(f'The interval is from {left:.4f} to {right:.4f}')
# Out:
# The interval is from 2.8441 to 3.5559

# %%
t_sample = (3.2 - mean)/(std/np.sqrt(n))
print(f't-sample is {t_sample:.4f}')
# Out:
# t-sample is 0.0000

# %%
df = 5
xvalue = 2.571
xticks = [-xvalue, -1, 0, 1, xvalue]
x_fill_1 = np.linspace(t.ppf(0.01, df), -xvalue, 100)
y_fill_1 = t.pdf(x_fill_1, df)
x_fill_2 = np.linspace(xvalue, t.ppf(0.99, df), 100)
y_fill_2 = t.pdf(x_fill_2, df)

# %%
fig, ax = plt.subplots(1, 1)
area = 1 - (t.cdf(xvalue, df) - t.cdf(-xvalue, df))
x = np.linspace(t.ppf(0.01, df), t.ppf(0.99, df), 100)
ax.plot(x, t.pdf(x, df), 'b-', lw=2, alpha=0.6, label=f't(df={df})')
ax.axvline(-xvalue, color='r', lw=2, alpha=0.5)
ax.axvline(xvalue, color='r', lw=2, alpha=0.5)
ax.axvline(t_sample, color='green', alpha=0.7, label=r'$t_{obs}=$'+f'{t_sample:.3f}')
ax.axhline(0, color='black')
title = f'P(X<{-xvalue})+P(X>{xvalue})={area:.2f}'
ax.set_title(title)
ax.set_xticks(xticks)

ax.fill_between(x_fill_1, y_fill_1, 0, alpha=0.3, color='b')
ax.fill_between(x_fill_2, y_fill_2, 0, alpha=0.3, color='b')
ax.legend()
ax.set_ylim(0, 0.42)
plt.tight_layout()
#plt.savefig('HW8_Q3.png', dpi=150)
plt.show()

# %%
t_critical = 4.032
left = mean - t_critical * std/np.sqrt(n)
right = mean + t_critical * std/np.sqrt(n)
print(f'The interval is from {left:.4f} to {right:.4f}')
# Out:
# The interval is from 2.6418 to 3.7582

# %%
df = 5
xvalue = 4.032
xticks = [-xvalue, -2 , 0, 2, xvalue]
x_fill_1 = np.linspace(t.ppf(0.001, df), -xvalue, 100)
y_fill_1 = t.pdf(x_fill_1, df)
x_fill_2 = np.linspace(xvalue, t.ppf(0.999, df), 100)
y_fill_2 = t.pdf(x_fill_2, df)

# %%
fig, ax = plt.subplots(1, 1)
area = 1 - (t.cdf(xvalue, df) - t.cdf(-xvalue, df))
x = np.linspace(t.ppf(0.001, df), t.ppf(0.999, df), 100)
ax.plot(x, t.pdf(x, df), 'b-', lw=2, alpha=0.6, label=f't(df={df})')
ax.axvline(-xvalue, color='r', lw=2, alpha=0.5)
ax.axvline(xvalue, color='r', lw=2, alpha=0.5)
ax.axvline(t_sample, color='green', alpha=0.7, label=r'$t_{obs}=$'+f'{t_sample:.3f}')
ax.axhline(0, color='black')
title = f'P(X<{-xvalue})+P(X>{xvalue})={area:.2f}'
ax.set_title(title)
ax.set_xticks(xticks)

ax.fill_between(x_fill_1, y_fill_1, 0, alpha=0.3, color='b')
ax.fill_between(x_fill_2, y_fill_2, 0, alpha=0.3, color='b')
ax.legend()
ax.set_ylim(0, 0.42)
plt.tight_layout()
#plt.savefig('HW8_Q3.png', dpi=150)
plt.show()

# %%
t_critical = 2.069
n = 24
left = mean - t_critical * std/np.sqrt(n)
right = mean + t_critical * std/np.sqrt(n)
print(f'The interval is from {left:.4f} to {right:.4f}')
# Out:
# The interval is from 3.0568 to 3.3432

# %%
df = 23
xvalue = 2.069
xticks = [-xvalue, -1 , 0, 1, xvalue]
x_fill_1 = np.linspace(t.ppf(0.001, df), -xvalue, 100)
y_fill_1 = t.pdf(x_fill_1, df)
x_fill_2 = np.linspace(xvalue, t.ppf(0.999, df), 100)
y_fill_2 = t.pdf(x_fill_2, df)

# %%
fig, ax = plt.subplots(1, 1)
area = 1 - (t.cdf(xvalue, df) - t.cdf(-xvalue, df))
x = np.linspace(t.ppf(0.001, df), t.ppf(0.999, df), 100)
ax.plot(x, t.pdf(x, df), 'b-', lw=2, alpha=0.6, label=f't(df={df})')
ax.axvline(-xvalue, color='r', lw=2, alpha=0.5)
ax.axvline(xvalue, color='r', lw=2, alpha=0.5)
ax.axvline(t_sample, color='green', alpha=0.7, label=r'$t_{obs}=$'+f'{t_sample:.3f}')
ax.axhline(0, color='black')
title = f'P(X<{-xvalue})+P(X>{xvalue})={area:.2f}'
ax.set_title(title)
ax.set_xticks(xticks)

ax.fill_between(x_fill_1, y_fill_1, 0, alpha=0.3, color='b')
ax.fill_between(x_fill_2, y_fill_2, 0, alpha=0.3, color='b')
ax.legend()
ax.set_ylim(0, 0.42)
plt.tight_layout()
#plt.savefig('HW8_Q3.png', dpi=150)
plt.show()

# %% [markdown]
# <h2 style="color:blue">Q5</h2>

# %%
n = 20
df = n-1
mu_0 = 15
mean = 17.5
std = 5.9
print(f'Sample mean is {mean:.2f}')
print(f'STD is {std:.2f}')
# Out:
# Sample mean is 17.50
# STD is 5.90

# %%
fig, ax = plt.subplots(1, 1)
x = np.linspace(t.ppf(0.001, df), t.ppf(0.999, df), 100)
ax.plot(x, t.pdf(x, df), 'b-', lw=2, alpha=0.6, label=f't(df={df})')
ax.plot(x, norm.pdf(x), '--', color='grey', lw=2, alpha=0.6, label=f'Normal')
ax.legend(fontsize=12)
plt.tight_layout()
#plt.savefig('HW8_Q5_1.png', dpi=150)
plt.show()

# %%
t_obs = (mean - mu_0) / ( std / np.sqrt(n))
print(f't_obs is {t_obs:.3f}')
# Out:
# t_obs is 1.895

# %%
xvalue = t_obs
xticks = [-3, -xvalue, -1 , 0, 1, xvalue, 3]
x_fill_1 = np.linspace(t.ppf(0.001, df), -xvalue, 100)
y_fill_1 = t.pdf(x_fill_1, df)
x_fill_2 = np.linspace(xvalue, t.ppf(0.999, df), 100)
y_fill_2 = t.pdf(x_fill_2, df)

# %%
fig, ax = plt.subplots(1, 1)
x = np.linspace(t.ppf(0.001, df), t.ppf(0.999, df), 100)
ax.plot(x, t.pdf(x, df), 'b-', lw=2, alpha=0.6, label=f't(df={df})')

ax.axvline(-xvalue, color='r', lw=2, alpha=0.5)
ax.axvline(xvalue, color='r', lw=2, alpha=0.5)
ax.set_xticks(xticks)
ax.legend(fontsize=12)

ax.fill_between(x_fill_1, y_fill_1, 0, alpha=0.3, color='b')
ax.fill_between(x_fill_2, y_fill_2, 0, alpha=0.3, color='b')

area = 1 - (t.cdf(xvalue, df) - t.cdf(-xvalue, df))
title = f'P(X<{-xvalue:.3f})+P(X>{xvalue:.3f})={area:.2f}'
ax.set_title(title)

plt.tight_layout()
#plt.savefig('HW8_Q5_2.png', dpi=150)
plt.show()

# %%
fig, ax = plt.subplots(1, 1)
x = np.linspace(t.ppf(0.001, df), t.ppf(0.999, df), 100)
ax.plot(x, t.pdf(x, df), 'b-', lw=2, alpha=0.6, label=f't(df={df})')

#ax.axvline(-xvalue, color='r', lw=2, alpha=0.5)
ax.axvline(xvalue, color='r', lw=2, alpha=0.5)
ax.set_xticks(xticks)
ax.legend(fontsize=12)

#ax.fill_between(x_fill_1, y_fill_1, 0, alpha=0.3, color='b')
ax.fill_between(x_fill_2, y_fill_2, 0, alpha=0.3, color='b')

area = 1 - t.cdf(xvalue, df)
title = f'P(X>{xvalue:.3f})={area:.2f}'
ax.set_title(title)

plt.tight_layout()
#plt.savefig('HW8_Q5_4.png', dpi=150)
plt.show()

# %%
fig, ax = plt.subplots(1, 1)
x = np.linspace(t.ppf(0.001, df), t.ppf(0.999, df), 100)
ax.plot(x, t.pdf(x, df), 'b-', lw=2, alpha=0.6, label=f't(df={df})')

ax.axvline(-xvalue, color='r', lw=2, alpha=0.5)
#ax.axvline(xvalue, color='r', lw=2, alpha=0.5)
ax.set_xticks(xticks)
ax.legend(fontsize=12)

ax.fill_between(x_fill_1, y_fill_1, 0, alpha=0.3, color='b')
#ax.fill_between(x_fill_2, y_fill_2, 0, alpha=0.3, color='b')

area = t.cdf(-xvalue, df)
title = f'P(X<{-xvalue:.3f})={area:.2f}'
ax.set_title(title)

plt.tight_layout()
#plt.savefig('HW8_Q5_5.png', dpi=150)
plt.show()
